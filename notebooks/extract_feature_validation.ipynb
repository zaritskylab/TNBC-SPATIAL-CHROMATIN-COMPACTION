# %%
import os

from utils.auxiliary_func import *
from flim_analysis.feature_extraction.extract_features import create_all_feature_patches_df
from utils.data_func import *
import config.const as const

import pandas as pd

# %% [markdown]
# ## Whole image

# %%
df_file_path = os.path.join(const.FULL_TISSUE_DIR, 'core', "FLIM_features_full_tissue.csv")
full_tissue_features_df = pd.read_csv(df_file_path, dtype = {'leap_ID': str})
print(full_tissue_features_df.shape)
full_tissue_features_df.head()
# Out:
# (7603779, 22)
#   leap_ID  nucleus_label  X coordinate  Y coordinate  lifetime_mean  area  \
# 0     032              1   1335.169231   2723.292308       2.720446  65.0
# 1     032              2   1117.571429   3347.375000       2.923679  56.0
# 2     032              3   1234.854167   3566.583333       1.771021  48.0
# 3     032              4   1043.071429   2489.428571       3.386071  14.0
# 4     032              5    670.118644   3978.237288       2.304644  59.0
#
#      extent  solidity  perimeter  diameter_area  ...  perimeter_crofton  \
# 0  0.722222  0.928571  28.142136       9.097284  ...          29.361935
# 1  0.777778  0.949153  25.313708       8.444016  ...          26.680418
# 2  0.888889  1.000000  23.071068       7.817640  ...          24.554261
# 3  0.700000  0.875000  11.656854       4.222008  ...          13.732908
# 4  0.737500  0.967213  26.142136       8.667245  ...          27.465816
#
#    major_axis_length  orientation  diameter_max  eccentricity  \
# ...

# %%
df_file_path = os.path.join(const.FULL_TISSUE_DIR, 'core', "FLIM_features_full_tissue_with_mae.csv")
full_tissue_features_df = pd.read_csv(df_file_path, dtype = {'leap_ID': str})
print(full_tissue_features_df.shape)
full_tissue_features_df.head()
# Out:
# (7603779, 28)
#   leap_ID  nucleus_label  X coordinate  Y coordinate  lifetime_mean  area  \
# 0     015              1   3662.775510   1900.285714       4.114694  49.0
# 1     015              2   8580.090909   3129.590909       2.585364  22.0
# 2     015              3   4095.750000   2607.750000       3.944350  40.0
# 3     015              4   7298.384615   4566.615385       4.067385  13.0
# 4     015              5   7192.500000   3036.000000       4.134938  16.0
#
#      extent  solidity  perimeter  diameter_area  ...  density_radius_40  \
# 0  0.680556  0.907407  25.313708       7.898654  ...           0.006366
# 1  0.448980  0.709677  19.071068       5.292567  ...           0.009947
# 2  0.714286  0.930233  21.313708       7.136496  ...           0.013130
# 3  0.812500  1.000000  10.242641       4.068429  ...           0.006167
# 4  0.800000  1.000000  11.656854       4.513517  ...           0.000796
#
# ...

# %% [markdown]
# ## Patches

# %%
patches_df_1000 = read_patches_files(patch_size=1000, patch_overlap=0.75)
print(patches_df_1000.shape)
patches_df_1000.head(2)
# Out:
# (115744242, 7)
#   leap_ID            patch_ID  nucleus_label  lifetime_mean       category  \
# 0     044  1737_100_2737_1100             83       1.948000  non responder
# 1     044  1737_100_2737_1100            222       2.228013  non responder
#
#    X coordinate  Y coordinate
# 0   2713.000000   1023.500000
# 1   2688.922078    879.727273

# %%
print(patches_df_1000.isna().sum())
print(patches_df_1000[patches_df_1000.isna().any(axis=1)])
# Out:
# leap_ID          0
# patch_ID         0
# nucleus_label    0
# lifetime_mean    0
# category         0
# X coordinate     0
# Y coordinate     0
# dtype: int64
# Empty DataFrame
# Columns: [leap_ID, patch_ID, nucleus_label, lifetime_mean, category, X coordinate, Y coordinate]
# Index: []

# %%
patches_df_1500 = read_patches_files(patch_size=1500, patch_overlap=0.75)
print(patches_df_1500.shape)
patches_df_1500.head(2)
# Out:
# (107933477, 7)
#   leap_ID        patch_ID  nucleus_label  lifetime_mean       category  \
# 0     039  0_73_1500_1573              4       4.302937  non responder
# 1     039  0_73_1500_1573             13       1.020000  non responder
#
#    X coordinate  Y coordinate
# 0   1490.500000    831.000000
# 1   1503.988506    869.712644

# %%
print(patches_df_1500.isna().sum())
print(patches_df_1500[patches_df_1500.isna().any(axis=1)])
# Out:
# leap_ID          0
# patch_ID         0
# nucleus_label    0
# lifetime_mean    0
# category         0
# X coordinate     0
# Y coordinate     0
# dtype: int64
# Empty DataFrame
# Columns: [leap_ID, patch_ID, nucleus_label, lifetime_mean, category, X coordinate, Y coordinate]
# Index: []

# %%
patches_df_2000 = read_patches_files(patch_size=2000, patch_overlap=0.75)
print(patches_df_2000.shape)
patches_df_2000.head(2)
# Out:
# (99654342, 7)
#   leap_ID        patch_ID  nucleus_label  lifetime_mean       category  \
# 0     039  0_73_2000_2073              2       4.114737  non responder
# 1     039  0_73_2000_2073              4       4.302937  non responder
#
#    X coordinate  Y coordinate
# 0   1241.842105   1800.842105
# 1   1490.500000    831.000000

# %%
print(patches_df_2000.isna().sum())
print(patches_df_2000[patches_df_2000.isna().any(axis=1)])
# Out:
# leap_ID          0
# patch_ID         0
# nucleus_label    0
# lifetime_mean    0
# category         0
# X coordinate     0
# Y coordinate     0
# dtype: int64
# Empty DataFrame
# Columns: [leap_ID, patch_ID, nucleus_label, lifetime_mean, category, X coordinate, Y coordinate]
# Index: []

# %% [markdown]
# ## Resection

# %%
df_file_path = os.path.join(const.FULL_TISSUE_DIR, 'resection', "FLIM_features_full_tissue.csv")
full_tissue_resection_features_df = pd.read_csv(df_file_path, dtype = {'leap_ID': str})
print(full_tissue_resection_features_df.shape)
full_tissue_resection_features_df.head()
# Out:
# (12935730, 22)
#   leap_ID  nucleus_label  X coordinate  Y coordinate  lifetime_mean  area  \
# 0     047              6   7025.153846   9521.230769       2.996846  13.0
# 1     047              8  16023.588235  12636.117647       3.097412  17.0
# 2     047              9   4825.384615   3317.615385       3.096769  13.0
# 3     047             10   7671.866667   4725.466667       3.269400  15.0
# 4     047             11   8224.083333   6097.333333       3.087417  12.0
#
#    extent  solidity  perimeter  diameter_area  ...  perimeter_crofton  \
# 0  0.6500  0.928571  11.071068       4.068429  ...          13.177548
# 1  0.8500  1.000000  12.242641       4.652426  ...          14.288268
# 2  0.8125  1.000000  10.242641       4.068429  ...          12.392149
# 3  0.7500  0.937500  11.656854       4.370194  ...          13.732908
# 4  0.7500  1.000000  10.242641       3.908820  ...          12.392149
#
#    major_axis_length  orientation  diameter_max  eccentricity  \
# ...
