# %%
import pandas as pd
from utils.plots_func import *
import os
import config.const as const

# %% [markdown]
# # Feature Distributions By Response And Features Correlations With Lifetime

# %% [markdown]
# ### Define Parameters

# %%
data_preparation_dir = os.path.join(const.base_dir, 'figure_results', 'data_preparation')


figure_supplementary_dir = os.path.join(const.base_dir, 'figure_results', 'Supplementary')
os.makedirs(figure_supplementary_dir, exist_ok=True)

# %% [markdown]
# ### Lifetime correltion with another feature

# %%
df_file_path = os.path.join(data_preparation_dir, 'correlation_df_between_lifetime_and_morphological_density_features_core_resection.csv')


df_correlation = pd.read_csv(df_file_path, dtype = {'leap_ID': str})

# %%
plt_fig = plot_boxplot_by_category(df_correlation, 'Correlation', category_col='feature_name', figsize=(8,4))
save_fig(figure_supplementary_dir, 'correlation_by_feature_name', 'pdf', plt_fig)
# Out:
# /home/reutme/.conda/envs/flim_stardist/lib/python3.10/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/reutme/.conda/envs/flim_stardist/lib/python3.10/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Figure saved as pdf at: /sise/assafzar-group/assafzar/reut/Test_FLIM/from_FLIM_dir/figure_results/Supplementary/correlation_by_feature_name.pdf

# %% [markdown]
# ### Responder vs Non responder seperation by feature

# %%
df_median_file_path = os.path.join(data_preparation_dir, "features_median_data_core.csv")
median_df = pd.read_csv(df_median_file_path, dtype={'leap_ID': str})
median_df.head(2)
# Out:
#   leap_ID  lifetime_mean  area  extent  solidity  perimeter  diameter_area  \
# 0     015       3.915147  16.0    0.75  0.954545  12.242641       4.513517
# 1     017       4.177300  18.0    0.75  0.944444  13.656854       4.787307
#
#    convex_hull_area  minor_axis_length  perimeter_crofton  major_axis_length  \
# 0              17.0           3.669612          14.518306           5.449354
# 1              20.0           3.991464          16.184387           6.065440
#
#    orientation  diameter_max  eccentricity  density_radius_20  \
# 0     0.000000      5.385165      0.713180           0.007958
# 1     0.084918      6.324555      0.722862           0.019099
#
#    density_radius_40  density_radius_60  density_radius_80       category
# 0           0.005769           0.005040           0.004526  non responder
# 1           0.018104           0.016977           0.016015  non responder

# %%
plt_fig = category_seperation_by_feature(median_df, 'eccentricity', order = ['responder', 'non responder'])
save_fig(figure_supplementary_dir, 'eccentricity_reponder_non_responder', 'pdf', plt_fig)
# Out:
# /home/reutme/.conda/envs/flim_stardist/lib/python3.10/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/reutme/.conda/envs/flim_stardist/lib/python3.10/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# T-statistic: 0.3573732421232969
# P-value: 0.7225506490433115
# eccentricity auc - 0.5152173913043478
#
# Figure saved as pdf at: /sise/assafzar-group/assafzar/reut/Test_FLIM/from_FLIM_dir/figure_results/Supplementary/eccentricity_reponder_non_responder.pdf

# %%
plt_fig = category_seperation_by_feature(median_df, 'area', mapping={'non responder': 0, 'responder': 1}, order = ['responder', 'non responder'])
save_fig(figure_supplementary_dir, 'area_reponder_non_responder', 'pdf', plt_fig)
# Out:
# /home/reutme/.conda/envs/flim_stardist/lib/python3.10/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/reutme/.conda/envs/flim_stardist/lib/python3.10/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# T-statistic: -1.044066270310289
# P-value: 0.3019978688670676
# area auc - 0.6253623188405798
#
# Figure saved as pdf at: /sise/assafzar-group/assafzar/reut/Test_FLIM/from_FLIM_dir/figure_results/Supplementary/area_reponder_non_responder.pdf

# %%
plt_fig = category_seperation_by_feature(median_df, 'density_radius_40', mapping={'non responder': 0, 'responder': 1}, order = ['responder', 'non responder'])
save_fig(figure_supplementary_dir, 'density_reponder_non_responder', 'pdf', plt_fig)
# Out:
# /home/reutme/.conda/envs/flim_stardist/lib/python3.10/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/reutme/.conda/envs/flim_stardist/lib/python3.10/site-packages/seaborn/_core.py:1225: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# T-statistic: -0.8820241043676836
# P-value: 0.38275128125620195
# density_radius_40 auc - 0.5797101449275361
#
# Figure saved as pdf at: /sise/assafzar-group/assafzar/reut/Test_FLIM/from_FLIM_dir/figure_results/Supplementary/density_reponder_non_responder.pdf
